# %%
import pandas as pd

# %%
population_data= pd.read_csv('population_data.csv')

# %%
population_data
# Out:
#       Unnamed: 0      country continent  year  lifeExp       pop   gdpPercap  \
# 0              0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1              1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2              2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3              3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4              4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...          ...          ...       ...   ...      ...       ...         ...
# 1699        1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700        1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701        1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702        1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703        1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
#      iso_alpha  iso_num
# ...

# %%
population_data = population_data.drop(['country', 'continent', 'iso_alpha'], axis=1)
population_data
# Out:
#       Unnamed: 0  year  lifeExp       pop   gdpPercap  iso_num
# 0              0  1952   28.801   8425333  779.445314        4
# 1              1  1957   30.332   9240934  820.853030        4
# 2              2  1962   31.997  10267083  853.100710        4
# 3              3  1967   34.020  11537966  836.197138        4
# 4              4  1972   36.088  13079460  739.981106        4
# ...          ...   ...      ...       ...         ...      ...
# 1699        1699  1987   62.351   9216418  706.157306      716
# 1700        1700  1992   60.377  10704340  693.420786      716
# 1701        1701  1997   46.809  11404948  792.449960      716
# 1702        1702  2002   39.989  11926563  672.038623      716
# 1703        1703  2007   43.487  12311143  469.709298      716
#
# [1704 rows x 6 columns]

# %%
Y = population_data.gdpPercap # Dependent variable (target)
Y = Y.values
Y
# Out:
# array([779.4453145, 820.8530296, 853.10071  , ..., 792.4499603,
#        672.0386227, 469.7092981], shape=(1704,))

# %%
X = population_data.drop(['gdpPercap'], axis=1) # independent variables
X = X.values
X
# Out:
# array([[0.0000000e+00, 1.9520000e+03, 2.8801000e+01, 8.4253330e+06,
#         4.0000000e+00],
#        [1.0000000e+00, 1.9570000e+03, 3.0332000e+01, 9.2409340e+06,
#         4.0000000e+00],
#        [2.0000000e+00, 1.9620000e+03, 3.1997000e+01, 1.0267083e+07,
#         4.0000000e+00],
#        ...,
#        [1.7010000e+03, 1.9970000e+03, 4.6809000e+01, 1.1404948e+07,
#         7.1600000e+02],
#        [1.7020000e+03, 2.0020000e+03, 3.9989000e+01, 1.1926563e+07,
#         7.1600000e+02],
#        [1.7030000e+03, 2.0070000e+03, 4.3487000e+01, 1.2311143e+07,
#         7.1600000e+02]], shape=(1704, 5))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size= 0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((1363, 5), (1363,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((341, 5), (341,))

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
pop_model = linear_model.LinearRegression()

# %%
pop_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = pop_model.predict(X_test)

# %%
print('Coefficients:', pop_model.coef_)
print('Intercept:', pop_model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_test, Y_pred))
# Out:
# Coefficients: [-2.40893260e+00 -3.13067680e+01  4.80025570e+02 -5.65866137e-06
#   4.46276307e+00]
# Intercept: 41162.656941637055
# Mean squared error (MSE): 37111052.36
# Coefficient of determination (R^2): 0.41

# %%
population_data.head()
# Out:
#    Unnamed: 0  year  lifeExp       pop   gdpPercap  iso_num
# 0           0  1952   28.801   8425333  779.445314        4
# 1           1  1957   30.332   9240934  820.853030        4
# 2           2  1962   31.997  10267083  853.100710        4
# 3           3  1967   34.020  11537966  836.197138        4
# 4           4  1972   36.088  13079460  739.981106        4

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.4113200872086027

# %%
import seaborn as sns

# %%
Y_test
# Out:
# array([ 7550.359877 ,   881.5706467,  2980.331339 ,  4616.896545 ,
#         1737.561657 ,  4649.593785 ,  6101.255823 , 13149.04119  ,
#         2627.009471 ,  5970.38876  ,  1056.353958 ,  2011.159549 ,
#         4269.276742 , 23235.42329  ,  5603.357717 ,  2750.364446 ,
#         1684.146528 ,  1213.315116 ,  4977.41854  ,   411.8006266,
#        15268.42089  ,   944.4383152,  7433.889293 ,  5444.648617 ,
#         1547.944844 ,  2760.196931 ,   734.7829124,  2291.156835 ,
#          566.2439442,  3081.694603 ,   375.6431231, 18115.22313  ,
#         5678.348271 , 11367.16112  ,  3822.137084 , 16672.14356  ,
#         2523.337977 ,  1561.769116 ,   676.9000921, 17541.49634  ,
#         9472.384295 ,   653.7301704, 10118.05318  ,  9576.037596 ,
#         4358.595393 ,  5487.104219 ,  2785.493582 ,  2497.437901 ,
#         1057.206311 ,   853.540919 ,  3076.239795 , 33519.4766   ,
#         2955.984375 ,  1267.613204 , 47306.98978  ,   986.2958956,
# ...

# %%
Y_pred
# Out:
# array([ 1.22337938e+04,  1.04272107e+03,  1.79964132e+03,  1.05027423e+04,
#         7.26591469e+03,  1.01210594e+04,  1.39258530e+04,  1.35637045e+04,
#         7.50763782e+03,  1.23437843e+04,  2.70419088e+03,  3.72092531e+03,
#        -3.95209434e+03,  1.23842435e+04,  1.24090216e+04,  2.23198906e+03,
#         1.94736314e+03,  3.23617728e+03,  1.20459914e+04,  2.43959933e+03,
#         1.50823113e+04,  1.13840892e+03,  1.23791199e+04,  1.14665815e+04,
#         4.18073562e+03,  1.13578786e+04, -3.33997786e+03,  2.73939233e+03,
#        -5.29354202e+01,  1.05811416e+04, -3.54484334e+03,  1.09541235e+04,
#         9.95052526e+03,  1.29451760e+04,  9.70495817e+03,  1.36439110e+04,
#         1.08100112e+04,  2.57219688e+03,  4.83923371e+03,  1.56206218e+04,
#         1.23715279e+04,  5.30429172e+03,  1.49458381e+04,  6.57555448e+03,
#         6.23190466e+03,  2.62195433e+03,  7.18421755e+03,  1.31289854e+04,
# ...

# %%
sns.scatterplot(x=Y_test, y=Y_pred, alpha=0.5)
# Out:
# <Axes: xlabel='None'>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(Y_test, Y_pred)
plt.ylabel("Y_pred")
plt.xlabel('Y_test')
# Out:
# Text(0.5, 0, 'Y_test')
